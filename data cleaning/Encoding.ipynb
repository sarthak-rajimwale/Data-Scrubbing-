# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv('unclean_data.csv')

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      665
# Female    333
# Other       2
# Name: count, dtype: int64

# %%
filt = (df['Gender'] == "Other")
df = df[~filt]

# %%
en_data=df['Gender']

# %%
pd.get_dummies(en_data)
# Out:
#      Female   Male
# 0     False   True
# 1     False   True
# 2      True  False
# 3     False   True
# 4      True  False
# ..      ...    ...
# 995   False   True
# 996   False   True
# 997   False   True
# 998    True  False
# 999    True  False
#
# [998 rows x 2 columns]

# %%
en_data_df = en_data.to_frame() 

ohe = OneHotEncoder(drop="first")
ar=ohe.fit_transform(en_data_df).toarray()

# %%
ohe_df=pd.DataFrame(ar,columns=["Male"])

# %%
df = pd.concat([df, ohe_df], axis=1)

# %%
df
# Out:
#           ID  Age  Gender Height (cm) Weight (kg) Income ($) Education Level  \
# 0     3887.0   21    Male         187          71        NaN      Bachelor's
# 1    93906.0   37    Male         172          47        NaN             NaN
# 2     4179.0   24  Female         146         106        NaN             NaN
# 3    33794.0   31    Male         190          66      74043      Bachelor's
# 4    52309.0   74  Female         181          60      82046             NaN
# ..       ...  ...     ...         ...         ...        ...             ...
# 997   7064.0   90    Male         195       Heavy        NaN        Master's
# 998  51200.0   64  Female         153          82      89681     High School
# 999  85292.0   30  Female         164          89        NaN        Master's
# 119      NaN  NaN     NaN         NaN         NaN        NaN             NaN
# 445      NaN  NaN     NaN         NaN         NaN        NaN             NaN
#
#      Male  Male
# 0     1.0   1.0
# 1     1.0   1.0
# 2     0.0   0.0
# 3     1.0   1.0
# 4     0.0   0.0
# ..    ...   ...
# 997   1.0   0.0
# 998   0.0   NaN
# 999   0.0   NaN
# 119   NaN   1.0
# 445   NaN   1.0
#
# [1000 rows x 9 columns]
