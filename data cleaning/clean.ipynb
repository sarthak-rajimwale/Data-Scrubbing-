# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('unclean_data.csv')

# %%
df.head()
# Out:
#       ID Age  Gender Height (cm) Weight (kg) Income ($) Education Level
# 0   3887  21     NaN         187          71        NaN      Bachelor's
# 1  93906  37     NaN         172          47        NaN             NaN
# 2   4179  24  Female         146         106        NaN             NaN
# 3  33794  31     NaN         190          66      74043      Bachelor's
# 4  52309  74  Female         181          60      82046             NaN

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.shape[0]
# Out:
# 1000

# %%
df.isnull().sum().sum()
# Out:
# 1357

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                  0.0
# Age                 1.1
# Gender             31.5
# Height (cm)         0.6
# Weight (kg)         0.6
# Income ($)         67.9
# Education Level    34.0
# dtype: float64

# %%
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# 19.385714285714286

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.drop(columns=["Income ($)"],inplace=True)

# %%
df
# Out:
#         ID Age  Gender Height (cm) Weight (kg) Education Level
# 0     3887  21     NaN         187          71      Bachelor's
# 1    93906  37     NaN         172          47             NaN
# 2     4179  24  Female         146         106             NaN
# 3    33794  31     NaN         190          66      Bachelor's
# 4    52309  74  Female         181          60             NaN
# ..     ...  ..     ...         ...         ...             ...
# 995  98674  48     NaN         192         127             NaN
# 996  37733  69    Male         168         114             NaN
# 997   7064  90    Male         195       Heavy        Master's
# 998  51200  64  Female         153          82     High School
# 999  85292  30  Female         164          89        Master's
#
# [1000 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         ID Age  Gender Height (cm) Weight (kg) Education Level
# 5    77058  29    Male         162          63             PhD
# 8    37963  85    Male         177          66      Bachelor's
# 10   68186  44  Female         156          52     High School
# 11   84786  77  Female         159          79        Master's
# 14   93143  85    Male         174          64     High School
# ..     ...  ..     ...         ...         ...             ...
# 992  86860  73  Female         195         132        Master's
# 994  51630  70  Female         165         111     High School
# 997   7064  90    Male         195       Heavy        Master's
# 998  51200  64  Female         153          82     High School
# 999  85292  30  Female         164          89        Master's
#
# [441 rows x 6 columns]
