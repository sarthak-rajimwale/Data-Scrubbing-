# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('cleaned_data.csv')

# %%
df
# Out:
#      Unnamed: 0     ID  Gender Education Level  Income ($)    Age  \
# 0             0   3887    Male      Bachelor's        21.0  187.0
# 1             1  93906    Male             PhD        37.0  172.0
# 2             2   4179  Female             PhD        24.0  146.0
# 3             3  33794    Male      Bachelor's        31.0  190.0
# 4             4  52309  Female             PhD        74.0  181.0
# ..          ...    ...     ...             ...         ...    ...
# 995         995  98674    Male             PhD        48.0  192.0
# 996         996  37733    Male             PhD        69.0  168.0
# 997         997   7064    Male        Master's        90.0  195.0
# 998         998  51200  Female     High School        64.0  153.0
# 999         999  85292  Female        Master's        30.0  164.0
#
#      Height (cm)   Weight (kg)
# 0      71.000000  50292.895082
# 1      47.000000  50292.895082
# 2     106.000000  50292.895082
# 3      66.000000  74043.000000
# 4      60.000000  82046.000000
# ..           ...           ...
# 995   127.000000  14709.000000
# 996   114.000000  50292.895082
# 997    94.621457  50292.895082
# 998    82.000000  89681.000000
# 999    89.000000  50292.895082
#
# [1000 rows x 8 columns]

# %%
df_=pd.DataFrame({'Name':['Sarthak','Mansi','Devansh']})

# %%
le=LabelEncoder()
df_['en_name']=le.fit_transform(df_['Name'])

# %%
df_
# Out:
#       Name  en_name
# 0  Sarthak        2
# 1    Mansi        1
# 2  Devansh        0

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#         ID  Gender Education Level  Income ($)    Age  Height (cm)  \
# 0     3887    Male      Bachelor's        21.0  187.0    71.000000
# 1    93906    Male             PhD        37.0  172.0    47.000000
# 2     4179  Female             PhD        24.0  146.0   106.000000
# 3    33794    Male      Bachelor's        31.0  190.0    66.000000
# 4    52309  Female             PhD        74.0  181.0    60.000000
# ..     ...     ...             ...         ...    ...          ...
# 995  98674    Male             PhD        48.0  192.0   127.000000
# 996  37733    Male             PhD        69.0  168.0   114.000000
# 997   7064    Male        Master's        90.0  195.0    94.621457
# 998  51200  Female     High School        64.0  153.0    82.000000
# 999  85292  Female        Master's        30.0  164.0    89.000000
#
#       Weight (kg)
# 0    50292.895082
# 1    50292.895082
# 2    50292.895082
# 3    74043.000000
# 4    82046.000000
# ..            ...
# 995  14709.000000
# 996  50292.895082
# 997  50292.895082
# 998  89681.000000
# 999  50292.895082
#
# [1000 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# ID                 0
# Gender             0
# Education Level    0
# Income ($)         0
# Age                0
# Height (cm)        0
# Weight (kg)        0
# dtype: int64

# %%
en=LabelEncoder()
en.fit(df['Education Level'])
# Out:
# LabelEncoder()

# %%
df['Education Level']=en.transform(df['Education Level'])

# %%
df
# Out:
#         ID  Gender  Education Level  Income ($)    Age  Height (cm)  \
# 0     3887    Male                0        21.0  187.0    71.000000
# 1    93906    Male                5        37.0  172.0    47.000000
# 2     4179  Female                5        24.0  146.0   106.000000
# 3    33794    Male                0        31.0  190.0    66.000000
# 4    52309  Female                5        74.0  181.0    60.000000
# ..     ...     ...              ...         ...    ...          ...
# 995  98674    Male                5        48.0  192.0   127.000000
# 996  37733    Male                5        69.0  168.0   114.000000
# 997   7064    Male                3        90.0  195.0    94.621457
# 998  51200  Female                2        64.0  153.0    82.000000
# 999  85292  Female                3        30.0  164.0    89.000000
#
#       Weight (kg)
# 0    50292.895082
# 1    50292.895082
# 2    50292.895082
# 3    74043.000000
# 4    82046.000000
# ..            ...
# 995  14709.000000
# 996  50292.895082
# 997  50292.895082
# 998  89681.000000
# 999  50292.895082
#
# [1000 rows x 7 columns]
